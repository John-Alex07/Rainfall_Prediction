# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../Dataset/weatherAUS.csv")

# %%
df = df.loc[:, ['Sunshine', 'Cloud9am', 'Cloud3pm']]

# %%
df.head()
# Out:
#    Sunshine  Cloud9am  Cloud3pm
# 0       NaN       8.0       NaN
# 1       NaN       NaN       NaN
# 2       NaN       NaN       2.0
# 3       NaN       NaN       NaN
# 4       NaN       7.0       8.0

# %%
df_original = df.dropna()
df_original
# Out:
#         Sunshine  Cloud9am  Cloud3pm
# 5939        12.3       2.0       5.0
# 5940        13.0       1.0       1.0
# 5942        10.6       1.0       6.0
# 5943        12.2       1.0       5.0
# 5944         8.4       1.0       6.0
# ...          ...       ...       ...
# 139108      11.0       0.0       1.0
# 139109       8.6       7.0       0.0
# 139110      11.0       0.0       0.0
# 139111      10.6       1.0       1.0
# 139112      10.7       6.0       5.0
#
# [64416 rows x 3 columns]

# %%
# Drop rows with atleast 2 NaN values

df = df.dropna(thresh=2)

# %%
# Extracting rows in which Sunshine is NaN

df_fill_sunshine = df[df['Sunshine'].isnull()]
df_fill_sunshine
# Out:
#         Sunshine  Cloud9am  Cloud3pm
# 4            NaN       7.0       8.0
# 11           NaN       8.0       8.0
# 12           NaN       8.0       8.0
# 15           NaN       8.0       1.0
# 16           NaN       8.0       1.0
# ...          ...       ...       ...
# 142162       NaN       7.0       1.0
# 142163       NaN       4.0       7.0
# 142166       NaN       8.0       8.0
# 142167       NaN       8.0       4.0
# 142192       NaN       3.0       2.0
#
# [16703 rows x 3 columns]

# %%
# Extracting rows in which Cloud9am is NaN

df_fill_cloud9am = df[df['Cloud9am'].isnull()]
df_fill_cloud9am
# Out:
#         Sunshine  Cloud9am  Cloud3pm
# 5941        13.3       NaN       1.0
# 6011        11.5       NaN       3.0
# 6099        10.0       NaN       4.0
# 6434        10.0       NaN       0.0
# 12851        2.8       NaN       7.0
# ...          ...       ...       ...
# 134650       0.0       NaN       8.0
# 134754       2.0       NaN       7.0
# 135368      10.4       NaN       5.0
# 135395      12.3       NaN       4.0
# 138579       6.7       NaN       6.0
#
# [477 rows x 3 columns]

# %%
# Extracting rows in which Cloud3pm is NaN

df_fill_cloud3pm = df[df['Cloud3pm'].isnull()]
df_fill_cloud3pm
# Out:
#         Sunshine  Cloud9am  Cloud3pm
# 6118         7.1       5.0       NaN
# 6190        11.3       0.0       NaN
# 6428        10.3       1.0       NaN
# 9057         9.0       3.0       NaN
# 9432         9.1       1.0       NaN
# ...          ...       ...       ...
# 135332      12.9       0.0       NaN
# 135404      12.2       7.0       NaN
# 135448      12.0       0.0       NaN
# 136259       9.2       7.0       NaN
# 137545       4.8       6.0       NaN
#
# [2063 rows x 3 columns]

# %%
# Creating a Linear Regression model to predict Sunshine which will be used to fill NaN values

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X = df_original.loc[:, ['Cloud9am', 'Cloud3pm']]
y = df_original.loc[:, 'Sunshine']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model_sunshine = LinearRegression()

# %%
model_sunshine.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Using model to fill Nan values in Sunshine

df_fill_sunshine.loc[:, 'Sunshine'] = model_sunshine.predict(df_fill_sunshine.loc[:, ['Cloud9am', 'Cloud3pm']])
# Out:
# C:\Users\jonua\AppData\Local\Temp\ipykernel_43660\1718369687.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fill_sunshine.loc[:, 'Sunshine'] = model_sunshine.predict(df_fill_sunshine.loc[:, ['Cloud9am', 'Cloud3pm']])

# %%
df_fill_sunshine
# Out:
#         Sunshine  Cloud9am  Cloud3pm
# 4       3.806472       7.0       8.0
# 11      3.277427       8.0       8.0
# 12      3.277427       8.0       8.0
# 15      7.861042       8.0       1.0
# 16      7.861042       8.0       1.0
# ...          ...       ...       ...
# 142162  8.390088       7.0       1.0
# 142163  6.048411       4.0       7.0
# 142166  3.277427       8.0       8.0
# 142167  5.896636       8.0       4.0
# 142192  9.851467       3.0       2.0
#
# [16703 rows x 3 columns]

# %%
# Replace the rows in df with rows in df_fill_sunshine only at indexes of df_fill_sunshine

df.loc[df_fill_sunshine.index, 'Sunshine'] = df_fill_sunshine.loc[:, 'Sunshine']
df
# Out:
#         Sunshine  Cloud9am  Cloud3pm
# 4       3.806472       7.0       8.0
# 11      3.277427       8.0       8.0
# 12      3.277427       8.0       8.0
# 15      7.861042       8.0       1.0
# 16      7.861042       8.0       1.0
# ...          ...       ...       ...
# 142162  8.390088       7.0       1.0
# 142163  6.048411       4.0       7.0
# 142166  3.277427       8.0       8.0
# 142167  5.896636       8.0       4.0
# 142192  9.851467       3.0       2.0
#
# [83659 rows x 3 columns]

# %%
# Creating a Linear Regression model to predict Cloud9am which will be used to fill NaN values

X = df_original.loc[:, ['Sunshine', 'Cloud3pm']]
y = df_original.loc[:, 'Cloud9am']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model_cloud9am = LinearRegression()

model_cloud9am.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Using model to fill Nan values in Cloud9am

df_fill_cloud9am.loc[:, 'Cloud9am'] = model_cloud9am.predict(df_fill_cloud9am.loc[:, ['Sunshine', 'Cloud3pm']])
df_fill_cloud9am
# Out:
# C:\Users\jonua\AppData\Local\Temp\ipykernel_43660\3297994645.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fill_cloud9am.loc[:, 'Cloud9am'] = model_cloud9am.predict(df_fill_cloud9am.loc[:, ['Sunshine', 'Cloud3pm']])
#         Sunshine  Cloud9am  Cloud3pm
# 5941        13.3  1.265277       1.0
# 6011        11.5  2.486738       3.0
# 6099        10.0  3.317072       4.0
# 6434        10.0  2.191774       0.0
# 12851        2.8  6.796293       7.0
# ...          ...       ...       ...
# 134650       0.0  8.102436       8.0
# 134754       2.0  7.089099       7.0
# 135368      10.4  3.451994       5.0
# 135395      12.3  2.475257       4.0
# 138579       6.7  5.087543       6.0
#
# [477 rows x 3 columns]

# %%
# Replace the rows in df with rows in df_fill_cloud9am only at indexes of df_fill_cloud9am

df.loc[df_fill_cloud9am.index, 'Cloud9am'] = df_fill_cloud9am.loc[:, 'Cloud9am']
df
# Out:
#         Sunshine  Cloud9am  Cloud3pm
# 4       3.806472       7.0       8.0
# 11      3.277427       8.0       8.0
# 12      3.277427       8.0       8.0
# 15      7.861042       8.0       1.0
# 16      7.861042       8.0       1.0
# ...          ...       ...       ...
# 142162  8.390088       7.0       1.0
# 142163  6.048411       4.0       7.0
# 142166  3.277427       8.0       8.0
# 142167  5.896636       8.0       4.0
# 142192  9.851467       3.0       2.0
#
# [83659 rows x 3 columns]

# %%
# Creating a Linear Regression model to predict Cloud3pm which will be used to fill NaN values

X = df_original.loc[:, ['Sunshine', 'Cloud9am']]
y = df_original.loc[:, 'Cloud3pm']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model_cloud3pm = LinearRegression()

model_cloud3pm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Using model to fill Nan values in Cloud3pm

df_fill_cloud3pm.loc[:, 'Cloud3pm'] = model_cloud3pm.predict(df_fill_cloud3pm.loc[:, ['Sunshine', 'Cloud9am']])
df_fill_cloud3pm
# Out:
# C:\Users\jonua\AppData\Local\Temp\ipykernel_43660\739785622.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fill_cloud3pm.loc[:, 'Cloud3pm'] = model_cloud3pm.predict(df_fill_cloud3pm.loc[:, ['Sunshine', 'Cloud9am']])
#         Sunshine  Cloud9am  Cloud3pm
# 6118         7.1       5.0  4.714002
# 6190        11.3       0.0  1.945972
# 6428        10.3       1.0  2.559865
# 9057         9.0       3.0  3.523896
# 9432         9.1       1.0  3.012014
# ...          ...       ...       ...
# 135332      12.9       0.0  1.343105
# 135404      12.2       7.0  3.266567
# 135448      12.0       0.0  1.682218
# 136259       9.2       7.0  4.396942
# 137545       4.8       6.0  5.817724
#
# [2063 rows x 3 columns]

# %%
# Replace the rows in df with rows in df_fill_cloud3pm only at indexes of df_fill_cloud3pm

df.loc[df_fill_cloud3pm.index, 'Cloud3pm'] = df_fill_cloud3pm.loc[:, 'Cloud3pm']
df
# Out:
#         Sunshine  Cloud9am  Cloud3pm
# 4       3.806472       7.0       8.0
# 11      3.277427       8.0       8.0
# 12      3.277427       8.0       8.0
# 15      7.861042       8.0       1.0
# 16      7.861042       8.0       1.0
# ...          ...       ...       ...
# 142162  8.390088       7.0       1.0
# 142163  6.048411       4.0       7.0
# 142166  3.277427       8.0       8.0
# 142167  5.896636       8.0       4.0
# 142192  9.851467       3.0       2.0
#
# [83659 rows x 3 columns]

# %%
# Checking for NaN values

df.isnull().sum()
# Out:
# Sunshine    0
# Cloud9am    0
# Cloud3pm    0
# dtype: int64

# %%
df.describe()
# Out:
#            Sunshine      Cloud9am      Cloud3pm
# count  83659.000000  83659.000000  83659.000000
# mean       7.465358      4.434595      4.494955
# std        3.652684      2.873674      2.696974
# min        0.000000      0.000000      0.000000
# 25%        4.461275      1.000000      2.000000
# 50%        8.000000      5.000000      5.000000
# 75%       10.500000      7.000000      7.000000
# max       14.500000      9.000000      9.000000

# %%
# Saving df as a csv file along with the index

# df.to_csv("../Dataset/weatherAUS_cleaned.csv", index=True)

# %%
dat = pd.read_csv("../Dataset/weatherAUS.csv")
dat
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 142188  2017-06-20    Uluru      3.5     21.8       0.0          NaN
# 142189  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 142190  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 142191  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 142192  2017-06-24    Uluru      7.8     27.0       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  \
# 0            NaN           W           44.0          W  ...        22.0
# 1            NaN         WNW           44.0        NNW  ...        25.0
# 2            NaN         WSW           46.0          W  ...        30.0
# 3            NaN          NE           24.0         SE  ...        16.0
# 4            NaN           W           41.0        ENE  ...        33.0
# ...          ...         ...            ...        ...  ...         ...
# 142188       NaN           E           31.0        ESE  ...        27.0
# 142189       NaN           E           31.0         SE  ...        24.0
# 142190       NaN         NNW           22.0         SE  ...        21.0
# 142191       NaN           N           37.0         SE  ...        24.0
# 142192       NaN          SE           28.0        SSE  ...        24.0
#
#         Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 0            1007.7       1007.1       8.0       NaN     16.9     21.8
# 1            1010.6       1007.8       NaN       NaN     17.2     24.3
# 2            1007.6       1008.7       NaN       2.0     21.0     23.2
# 3            1017.6       1012.8       NaN       NaN     18.1     26.5
# 4            1010.8       1006.0       7.0       8.0     17.8     29.7
# ...             ...          ...       ...       ...      ...      ...
# 142188       1024.7       1021.2       NaN       NaN      9.4     20.9
# 142189       1024.6       1020.3       NaN       NaN     10.1     22.4
# 142190       1023.5       1019.1       NaN       NaN     10.9     24.5
# 142191       1021.0       1016.8       NaN       NaN     12.5     26.1
# 142192       1019.4       1016.5       3.0       2.0     15.1     26.0
#
#         RainToday  RISK_MM  RainTomorrow
# 0              No      0.0            No
# 1              No      0.0            No
# 2              No      0.0            No
# 3              No      1.0            No
# 4              No      0.2            No
# ...           ...      ...           ...
# 142188         No      0.0            No
# 142189         No      0.0            No
# 142190         No      0.0            No
# 142191         No      0.0            No
# 142192         No      0.0            No
#
# [142193 rows x 24 columns]

# %%
df
# Out:
#         Sunshine  Cloud9am  Cloud3pm
# 4       3.806472       7.0       8.0
# 11      3.277427       8.0       8.0
# 12      3.277427       8.0       8.0
# 15      7.861042       8.0       1.0
# 16      7.861042       8.0       1.0
# ...          ...       ...       ...
# 142162  8.390088       7.0       1.0
# 142163  6.048411       4.0       7.0
# 142166  3.277427       8.0       8.0
# 142167  5.896636       8.0       4.0
# 142192  9.851467       3.0       2.0
#
# [83659 rows x 3 columns]

# %%
# Replacing values of Cloud9am and Cloud3pm in dat with values in df at the same index

dat.loc[df.index, 'Cloud9am'] = df.loc[:, 'Cloud9am']
dat.loc[df.index, 'Cloud3pm'] = df.loc[:, 'Cloud3pm']
dat
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 142188  2017-06-20    Uluru      3.5     21.8       0.0          NaN
# 142189  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 142190  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 142191  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 142192  2017-06-24    Uluru      7.8     27.0       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  \
# 0            NaN           W           44.0          W  ...        22.0
# 1            NaN         WNW           44.0        NNW  ...        25.0
# 2            NaN         WSW           46.0          W  ...        30.0
# 3            NaN          NE           24.0         SE  ...        16.0
# 4       3.806472           W           41.0        ENE  ...        33.0
# ...          ...         ...            ...        ...  ...         ...
# 142188       NaN           E           31.0        ESE  ...        27.0
# 142189       NaN           E           31.0         SE  ...        24.0
# 142190       NaN         NNW           22.0         SE  ...        21.0
# 142191       NaN           N           37.0         SE  ...        24.0
# 142192  9.851467          SE           28.0        SSE  ...        24.0
#
#         Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 0            1007.7       1007.1       8.0       NaN     16.9     21.8
# 1            1010.6       1007.8       NaN       NaN     17.2     24.3
# 2            1007.6       1008.7       NaN       2.0     21.0     23.2
# 3            1017.6       1012.8       NaN       NaN     18.1     26.5
# 4            1010.8       1006.0       7.0       8.0     17.8     29.7
# ...             ...          ...       ...       ...      ...      ...
# 142188       1024.7       1021.2       NaN       NaN      9.4     20.9
# 142189       1024.6       1020.3       NaN       NaN     10.1     22.4
# 142190       1023.5       1019.1       NaN       NaN     10.9     24.5
# 142191       1021.0       1016.8       NaN       NaN     12.5     26.1
# 142192       1019.4       1016.5       3.0       2.0     15.1     26.0
#
#         RainToday  RISK_MM  RainTomorrow
# 0              No      0.0            No
# 1              No      0.0            No
# 2              No      0.0            No
# 3              No      1.0            No
# 4              No      0.2            No
# ...           ...      ...           ...
# 142188         No      0.0            No
# 142189         No      0.0            No
# 142190         No      0.0            No
# 142191         No      0.0            No
# 142192         No      0.0            No
#
# [142193 rows x 24 columns]

# %%
# Replacing values of sunshine in dat with values in df at the same index

dat.loc[df.index, 'Sunshine'] = df.loc[:, 'Sunshine']
dat
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 142188  2017-06-20    Uluru      3.5     21.8       0.0          NaN
# 142189  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 142190  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 142191  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 142192  2017-06-24    Uluru      7.8     27.0       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  \
# 0            NaN           W           44.0          W  ...        22.0
# 1            NaN         WNW           44.0        NNW  ...        25.0
# 2            NaN         WSW           46.0          W  ...        30.0
# 3            NaN          NE           24.0         SE  ...        16.0
# 4       3.806472           W           41.0        ENE  ...        33.0
# ...          ...         ...            ...        ...  ...         ...
# 142188       NaN           E           31.0        ESE  ...        27.0
# 142189       NaN           E           31.0         SE  ...        24.0
# 142190       NaN         NNW           22.0         SE  ...        21.0
# 142191       NaN           N           37.0         SE  ...        24.0
# 142192  9.851467          SE           28.0        SSE  ...        24.0
#
#         Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 0            1007.7       1007.1       8.0       NaN     16.9     21.8
# 1            1010.6       1007.8       NaN       NaN     17.2     24.3
# 2            1007.6       1008.7       NaN       2.0     21.0     23.2
# 3            1017.6       1012.8       NaN       NaN     18.1     26.5
# 4            1010.8       1006.0       7.0       8.0     17.8     29.7
# ...             ...          ...       ...       ...      ...      ...
# 142188       1024.7       1021.2       NaN       NaN      9.4     20.9
# 142189       1024.6       1020.3       NaN       NaN     10.1     22.4
# 142190       1023.5       1019.1       NaN       NaN     10.9     24.5
# 142191       1021.0       1016.8       NaN       NaN     12.5     26.1
# 142192       1019.4       1016.5       3.0       2.0     15.1     26.0
#
#         RainToday  RISK_MM  RainTomorrow
# 0              No      0.0            No
# 1              No      0.0            No
# 2              No      0.0            No
# 3              No      1.0            No
# 4              No      0.2            No
# ...           ...      ...           ...
# 142188         No      0.0            No
# 142189         No      0.0            No
# 142190         No      0.0            No
# 142191         No      0.0            No
# 142192         No      0.0            No
#
# [142193 rows x 24 columns]

# %%
dat.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp            637
# MaxTemp            322
# Rainfall          1406
# Evaporation      60843
# Sunshine         51113
# WindGustDir       9330
# WindGustSpeed     9270
# WindDir9am       10013
# WindDir3pm        3778
# WindSpeed9am      1348
# WindSpeed3pm      2630
# Humidity9am       1774
# Humidity3pm       3610
# Pressure9am      14014
# Pressure3pm      13981
# Cloud9am         53180
# Cloud3pm         55031
# Temp9am            904
# Temp3pm           2726
# RainToday         1406
# RISK_MM              0
# RainTomorrow         0
# dtype: int64

# %%
# Saving dat as a csv file replacing the original file

dat.to_csv("../Dataset/weatherAUS.csv", index=False)
